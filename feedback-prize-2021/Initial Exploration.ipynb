# %%
import fileinput
import pandas as pd

pd.set_option("display.max_rows", 101)
pd.set_option("display.max_colwidth", 500)

# %%
import spacy
from spacy import displacy

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from feedback.utils import *

# %%
train = pd.read_csv("input/train.csv", index_col="id")

# %%
train.loc["8006B9ECA272"]
# Out:
#               discourse_id  discourse_start  discourse_end  \
# id
# 8006B9ECA272  1.618628e+12              0.0          124.0
# 8006B9ECA272  1.618628e+12            132.0          221.0
# 8006B9ECA272  1.618628e+12            222.0          267.0
# 8006B9ECA272  1.618628e+12            271.0          323.0
# 8006B9ECA272  1.618628e+12            324.0          527.0
# 8006B9ECA272  1.618628e+12            528.0          813.0
# 8006B9ECA272  1.618628e+12            814.0         1077.0
# 8006B9ECA272  1.618628e+12           1078.0         1576.0
# 8006B9ECA272  1.618628e+12           1577.0         1708.0
# 8006B9ECA272  1.618628e+12           1709.0         2455.0
# 8006B9ECA272  1.618628e+12           2456.0         2771.0
#
# ...

# %%
submission = pd.read_csv("input/sample_submission.csv").id.unique()

# %%
submission
# Out:
# array(['18409261F5C2', 'D46BCB48440A', '0FB0700DAF44', 'D72CB1C11673',
#        'DF920E0A7337'], dtype=object)

# %%
# can i make it a good visualizer?

# would like to display a passage and color-code the components?
nlp = spacy.load("en_core_web_sm")

# %%
display_doc("8006B9ECA272")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Doc 8006B9ECA272</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #fef1d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     I think that the Facial Action Coding System used to read the emotion and expressions in students in a classroom is valuable
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Position</span>
# </mark>
#  because
# <mark class="entity" style="background: #a9fdd8; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#      it can be used for many different things such as potentionaly making people feel better,
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Claim</span>
# </mark>
#
# ...

# %%
display_doc("00213CD75AC3")
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Doc 00213CD75AC3</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #d7f8ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cars have been an issue to our community for a very long time. Car usage has been a problem to our pollution and emission. Limiting car usage would be able to help eliminate the smog that is polluting. There are beneficial implications for carbon emissions and the environment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Lead</span>
# </mark>
# . May there be many ways that
# <mark class="entity" style="background: #fef1d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#      limiting car usage could be an advantage to us.
#
# ...
